# %%
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
name = ['kNN', 'RandomForest', 'CNN']
data = [0.843,0.832,0.953]
p = ax.bar(name,data)
ax.bar_label(p)
ax.set_ylabel("f1 score")
plt.show()
